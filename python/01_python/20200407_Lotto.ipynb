# %%
import random

# %%
# lotto = []

for n in range(128):
    lotto = []

    while True:

        number = random.randint(1, 45)

        if len(lotto) >= 6:
            lotto.sort()
            break

        if number not in lotto:
            lotto.append(number)
            
    n += 1
    
    print("{} : ".format(n), lotto)
# Out:
# 1 :  [1, 19, 22, 30, 34, 42]
# 2 :  [4, 6, 8, 10, 37, 43]
# 3 :  [18, 19, 31, 34, 39, 40]
# 4 :  [1, 5, 8, 10, 35, 43]
# 5 :  [18, 22, 30, 39, 40, 41]
# 6 :  [1, 5, 12, 22, 25, 33]
# 7 :  [5, 6, 25, 26, 28, 29]
# 8 :  [10, 16, 18, 23, 24, 40]
# 9 :  [5, 7, 10, 20, 25, 43]
# 10 :  [18, 24, 26, 34, 36, 45]
# 11 :  [1, 16, 18, 21, 35, 43]
# 12 :  [10, 18, 21, 25, 27, 40]
# 13 :  [16, 18, 19, 22, 25, 26]
# 14 :  [15, 29, 37, 38, 40, 45]
# 15 :  [4, 12, 18, 23, 43, 44]
# 16 :  [15, 17, 39, 40, 43, 45]
# 17 :  [11, 13, 21, 26, 34, 37]
# 18 :  [3, 12, 19, 28, 30, 39]
# 19 :  [14, 18, 23, 39, 40, 43]
# 20 :  [1, 3, 12, 19, 27, 31]
# 21 :  [2, 14, 20, 30, 40, 42]
# 22 :  [2, 8, 13, 34, 36, 43]
# 23 :  [1, 2, 10, 29, 36, 41]
# 24 :  [3, 29, 33, 39, 41, 42]
# 25 :  [10, 11, 12, 30, 37, 38]
# 26 :  [3, 4, 8, 19, 38, 45]
# 27 :  [8, 11, 15, 18, 41, 42]
# 28 :  [7, 9, 25, 26, 27, 40]
# 29 :  [10, 15, 21, 25, 27, 45]
# 30 :  [6, 20, 36, 37, 38, 42]
# 31 :  [6, 8, 18, 26, 33, 37]
# ...

# %%
l = []

for n in range(0, 129):
    
    number = random.randint(1,45)
    
    if len(lotto) >= 6:
        l.sort()
        break
        
    if number not in lotto:
        lotto.append(number)
        
    n += 1

l
# Out:
# []
